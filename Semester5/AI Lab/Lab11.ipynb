# %% [markdown]
# # Genetic Algorithm

# %%
import random
import matplotlib.pyplot as plt

# Define the target function to be maximized
def target_function(x):
    if x is None:
        return float('-inf') # Handle None case by returning a very Low fitness
    return -(x ** 2) + 8.8

# Genetic algorithm parameters
POPULATION_SIZE = 100
NUM_GENERATIONS = 100
MUTATION_RATE = 0.1

# Function to initialize a random individual
def initialize_individual():
    return random.uniform(-5, 5)

# Function to evaluate the fitness of an individual based on the target function
def evaluate_fitness(individual):
    return target_function(individual)

# Function to perform selection based on roulette wheel selection
def roulette_wheel_selection(population, fitness_values):
    total_fitness = sum(fitness_values)
    selected_value = random.uniform(0, total_fitness)
    cumulative_fitness = 0
    for i, fitness in enumerate(fitness_values):
        cumulative_fitness += fitness
        if cumulative_fitness >= selected_value:
            return population[i]

# Function to perform crossover (single-point crossover)
def crossover(parent1, parent2):
    if parent1 is None or parent2 is None:
        return initialize_individual() # Handle None case by reinitializing
    crossover_point = random.uniform(-5, 5)
    child = (parent1 + parent2) / 2 # Simple average crossover
    return child

# Function to perform mutation
def mutate(individual):
    mutation_value = random.uniform(-0.5, 0.5)
    return individual + mutation_value

# Main genetic algorithm function
def genetic_algorithm(population_size, num_generations, mutation_rate):
    population = [initialize_individual() for _ in range(population_size)]
    best_individual = None
    best_fitness = float('-inf')
    all_best_fitness = []

    for generation in range(num_generations):
        # Evaluate fitness for each individual in the population
        fitness_values = [evaluate_fitness(individual) for individual in population]

        # Select parents for reproduction
        parents = [roulette_wheel_selection(population, fitness_values) for _ in range(population_size)]

        # Perform crossover to generate offspring
        offspring = [crossover(parents[i % population_size], parents[(i + 1) % population_size]) for i in range(population_size)]
        # Perform mutation on offspring
        offspring = [mutate(individual) if random.random() < mutation_rate else individual for individual in offspring]
        # Replace the old population with the new population (parents + offspring)
        population = parents + offspring

        # Update the best individual and fitness
        current_best_index = fitness_values.index(max(fitness_values))
        current_best_fitness = fitness_values[current_best_index]

        if current_best_fitness > best_fitness:
            best_fitness = current_best_fitness
            best_individual = population[current_best_index]

        all_best_fitness.append(best_fitness)

        print(f"Generation {generation + 1}: Best Fitness = {best_fitness:.4f}")

    return best_individual

# Run the genetic algorithm
result = genetic_algorithm(POPULATION_SIZE, NUM_GENERATIONS, MUTATION_RATE)
print(f"\nOptimal Solution: {result}")
print(f"Optimal Fitness: {evaluate_fitness(result):.4f}")
# Out:
# Generation 1: Best Fitness = 8.7994
# Generation 2: Best Fitness = 8.7994
# Generation 3: Best Fitness = 8.7994
# Generation 4: Best Fitness = 8.8000
# Generation 5: Best Fitness = 8.8000
# Generation 6: Best Fitness = 8.8000
# Generation 7: Best Fitness = 8.8000
# Generation 8: Best Fitness = 8.8000
# Generation 9: Best Fitness = 8.8000
# Generation 10: Best Fitness = 8.8000
# Generation 11: Best Fitness = 8.8000
# Generation 12: Best Fitness = 8.8000
# Generation 13: Best Fitness = 8.8000
# Generation 14: Best Fitness = 8.8000
# Generation 15: Best Fitness = 8.8000
# Generation 16: Best Fitness = 8.8000
# Generation 17: Best Fitness = 8.8000
# Generation 18: Best Fitness = 8.8000
# Generation 19: Best Fitness = 8.8000
# Generation 20: Best Fitness = 8.8000
# Generation 21: Best Fitness = 8.8000
# Generation 22: Best Fitness = 8.8000
# Generation 23: Best Fitness = 8.8000
# Generation 24: Best Fitness = 8.8000
# Generation 25: Best Fitness = 8.8000
# Generation 26: Best Fitness = 8.8000
# Generation 27: Best Fitness = 8.8000
# Generation 28: Best Fitness = 8.8000
# Generation 29: Best Fitness = 8.8000
# Generation 30: Best Fitness = 8.8000
# Generation 31: Best Fitness = 8.8000
# Generation 32: Best Fitness = 8.8000
# Generation 33: Best Fitness = 8.8000
# Generation 34: Best Fitness = 8.8000
# Generation 35: Best Fitness = 8.8000
# Generation 36: Best Fitness = 8.8000
# Generation 37: Best Fitness = 8.8000
# Generation 38: Best Fitness = 8.8000
# Generation 39: Best Fitness = 8.8000
# Generation 40: Best Fitness = 8.8000
# Generation 41: Best Fitness = 8.8000
# Generation 42: Best Fitness = 8.8000
# Generation 43: Best Fitness = 8.8000
# Generation 44: Best Fitness = 8.8000
# Generation 45: Best Fitness = 8.8000
# Generation 46: Best Fitness = 8.8000
# Generation 47: Best Fitness = 8.8000
# Generation 48: Best Fitness = 8.8000
# Generation 49: Best Fitness = 8.8000
# Generation 50: Best Fitness = 8.8000
# Generation 51: Best Fitness = 8.8000
# Generation 52: Best Fitness = 8.8000
# Generation 53: Best Fitness = 8.8000
# Generation 54: Best Fitness = 8.8000
# Generation 55: Best Fitness = 8.8000
# Generation 56: Best Fitness = 8.8000
# Generation 57: Best Fitness = 8.8000
# Generation 58: Best Fitness = 8.8000
# Generation 59: Best Fitness = 8.8000
# Generation 60: Best Fitness = 8.8000
# Generation 61: Best Fitness = 8.8000
# Generation 62: Best Fitness = 8.8000
# Generation 63: Best Fitness = 8.8000
# Generation 64: Best Fitness = 8.8000
# Generation 65: Best Fitness = 8.8000
# Generation 66: Best Fitness = 8.8000
# Generation 67: Best Fitness = 8.8000
# Generation 68: Best Fitness = 8.8000
# Generation 69: Best Fitness = 8.8000
# Generation 70: Best Fitness = 8.8000
# Generation 71: Best Fitness = 8.8000
# Generation 72: Best Fitness = 8.8000
# Generation 73: Best Fitness = 8.8000
# Generation 74: Best Fitness = 8.8000
# Generation 75: Best Fitness = 8.8000
# Generation 76: Best Fitness = 8.8000
# Generation 77: Best Fitness = 8.8000
# Generation 78: Best Fitness = 8.8000
# Generation 79: Best Fitness = 8.8000
# Generation 80: Best Fitness = 8.8000
# Generation 81: Best Fitness = 8.8000
# Generation 82: Best Fitness = 8.8000
# Generation 83: Best Fitness = 8.8000
# Generation 84: Best Fitness = 8.8000
# Generation 85: Best Fitness = 8.8000
# Generation 86: Best Fitness = 8.8000
# Generation 87: Best Fitness = 8.8000
# Generation 88: Best Fitness = 8.8000
# Generation 89: Best Fitness = 8.8000
# Generation 90: Best Fitness = 8.8000
# Generation 91: Best Fitness = 8.8000
# Generation 92: Best Fitness = 8.8000
# Generation 93: Best Fitness = 8.8000
# Generation 94: Best Fitness = 8.8000
# Generation 95: Best Fitness = 8.8000
# Generation 96: Best Fitness = 8.8000
# Generation 97: Best Fitness = 8.8000
# Generation 98: Best Fitness = 8.8000
# Generation 99: Best Fitness = 8.8000
# Generation 100: Best Fitness = 8.8000
#
# Optimal Solution: -0.16212779919632003
# Optimal Fitness: 8.7737
